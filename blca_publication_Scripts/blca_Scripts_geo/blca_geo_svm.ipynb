# %%
import pandas as pd
import os

# %%
data_dir = '/home/jing/Phd_project/project_UCD_blca/blca_DATA/blca_DATA_103990'
geo_df = pd.read_csv(os.path.join(data_dir, 'GSE103990_Normalized_counts.txt'),sep='\t',index_col=0)

# %%
df = pd.read_csv('/home/jing/Downloads/blca_data/E-MTAB-4321.idf.txt', sep='\t', header=None, engine='python')
df.head(10)
metadata = dict(zip(df[0], df[1]))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df = pd.read_csv('/home/jing/Downloads/blca_data/E-MTAB-4321.idf.txt', sep='\t', header=None, engine='python')
#       2 df.head(10)
#       3 metadata = dict(zip(df[0], df[1]))
#
# ...

# %%
df = pd.read_csv('/home/jing/Downloads/GSE248167_raw_counts_GRCh38.p13_NCBI.tsv', sep='\t')

# %%
df
# Out:
#           GeneID  GSM7906706  GSM7906707  GSM7906711  GSM7906712  GSM7906715  \
# 0      100287102           1           1           2           1          12
# 1         653635         334         341         498         239        1073
# 2      102466751           7           7           6           6          21
# 3      107985730           0           0           0           0           1
# 4      100302278           0           0           0           0           0
# ...          ...         ...         ...         ...         ...         ...
# 39371       4541       39976       38355       24312       52113      104353
# 39372       4556        1932        1935        2619        5211       14553
# 39373       4519      129199      115204       75659      144358      397372
# 39374       4576         397         346         173         207         774
# 39375       4571         938         812         837         772        4671
#
# ...
