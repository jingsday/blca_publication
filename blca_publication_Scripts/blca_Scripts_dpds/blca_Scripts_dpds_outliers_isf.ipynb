# %%
import os
import pandas as pd
import numpy as np

import pylab as plt
import sklearn
import statistics
import scipy.stats
import matplotlib
matplotlib.rcParams.update({
    'font.size':20,
    'font.family':'DejaVu Sans', 
    'xtick.labelsize':20, 
    'ytick.labelsize':20, 
    'axes.labelsize':30, 
    'figure.figsize':(12, 8)
    })
import sklearn, sklearn.preprocessing, sklearn.decomposition
import matplotlib.patches as mpatches
from sklearn.ensemble import IsolationForest

# %%
wkdir= "/home/jing/Phd_project/project_UCD_blca/blca_publication_OUTPUT/blca_publication_OUTPUT_LINCS/"
data_year = "2020"
cell_name = "BC3C"

data_dir = os.path.join(wkdir,"00_outputs_" + data_year + "_" + cell_name)

# %%
data_file = os.path.join(data_dir, "Data_norm_" + data_year + "_" + cell_name+ ".xlsx")
Data_norm = pd.read_excel(data_file, index_col = 0)
display(Data_norm)

genes_list = Data_norm.columns.to_list()
print("Landmark genes in LINCS data:", len(genes_list), genes_list)

exp_id_list = Data_norm.index.to_list()
print("Experiments in LINCS data for " + cell_name + " cells:", len(exp_id_list), exp_id_list)
# Out:
#                           AARS     ABCB6     ABCC5     ABCF1     ABCF3  \
# ASG002_BC3C_24H:A03  -0.191254 -0.055246  0.039596 -0.256266 -0.040419
# ASG002_BC3C_24H:A04  -0.265754 -0.317496  0.118696 -0.136665 -0.301569
# ASG002_BC3C_24H:A05  -0.181954 -0.081597 -0.210304  1.559535 -0.019019
# ASG002_BC3C_24H:A06   0.033446  0.042404 -0.150154 -0.093165  0.053180
# ASG002_BC3C_24H:J13   0.204446  0.180704  0.089096 -0.054666  0.053381
# ...                        ...       ...       ...       ...       ...
# MOAR012_BC3C_24H:P20  0.647151  0.211700 -0.979200  0.597350 -0.375751
# MOAR012_BC3C_24H:P21  0.171800  0.046300 -0.145550 -0.295150  0.030849
# MOAR012_BC3C_24H:P22  0.648700  0.058749 -0.031700  0.408249 -0.753950
# MOAR012_BC3C_24H:P23  0.090499 -0.469300 -0.611800  0.873550 -0.788450
# MOAR012_BC3C_24H:P24  0.204801 -1.388700 -0.283400  0.744750 -1.431150
#
#                          ABHD4     ABHD6      ABL1     ACAA1     ACAT2  ...  \
# ASG002_BC3C_24H:A03  -0.590523 -0.159396 -0.074319  0.457981  0.409608  ...
# ASG002_BC3C_24H:A04  -0.403023  0.124804 -0.036470  0.311931  0.660457  ...
# ASG002_BC3C_24H:A05  -0.457423  0.071404  0.074080 -0.356119  0.498808  ...
# ASG002_BC3C_24H:A06  -0.053823  0.087704  0.167681 -0.601569  0.383308  ...
# ASG002_BC3C_24H:J13   0.044877 -0.277396 -0.157419  0.535681 -3.933493  ...
# ...                        ...       ...       ...       ...       ...  ...
# MOAR012_BC3C_24H:P20  0.388300  0.394524  0.120151 -0.166775 -1.129125  ...
# MOAR012_BC3C_24H:P21  0.420951  0.222075  0.179800  0.274724 -0.423975  ...
# MOAR012_BC3C_24H:P22  0.332200 -0.357525 -0.107650 -0.213575  0.074225  ...
# MOAR012_BC3C_24H:P23 -0.097199 -0.366575 -0.490600 -0.624675 -0.009275  ...
# MOAR012_BC3C_24H:P24 -0.518100 -0.002174 -0.096200  1.198824  0.138525  ...
#
#                          ZMIZ1     ZMYM2    ZNF131    ZNF274    ZNF318  \
# ASG002_BC3C_24H:A03   0.543203  0.494266 -0.011923 -0.225931  0.285054
# ASG002_BC3C_24H:A04  -0.565096 -0.088634  0.122977 -0.047931  0.141804
# ASG002_BC3C_24H:A05   0.226104 -0.228034 -0.121023 -0.075331 -0.133146
# ASG002_BC3C_24H:A06  -0.608596 -0.228835  0.072777  0.082970 -0.570996
# ASG002_BC3C_24H:J13  -0.318397  0.122265 -0.134323 -0.088931 -0.067996
# ...                        ...       ...       ...       ...       ...
# MOAR012_BC3C_24H:P20 -1.598475 -0.552750  0.515151  0.120800  0.082675
# MOAR012_BC3C_24H:P21 -1.650575  0.203600 -0.003250 -0.064800 -0.037675
# MOAR012_BC3C_24H:P22  0.127625  0.031600  0.103250 -0.249600  0.046375
# MOAR012_BC3C_24H:P23  0.054676 -0.596050  0.084600  0.444700  0.431375
# MOAR012_BC3C_24H:P24 -0.123474 -0.486500  0.049901 -0.598100 -0.259925
#
#                         ZNF395    ZNF451    ZNF586    ZNF589      ZW10
# ASG002_BC3C_24H:A03  -0.775246  0.166031 -0.024873  0.238723  0.284204
# ASG002_BC3C_24H:A04   0.129054 -0.028819 -0.028773 -0.253627 -0.752646
# ASG002_BC3C_24H:A05   0.355054  0.022831 -0.084073  0.283123 -0.894896
# ASG002_BC3C_24H:A06   2.847754 -0.211670 -0.067273  0.081723  0.338704
# ASG002_BC3C_24H:J13  -0.515847 -0.005069  0.067527  0.002223  0.204904
# ...                        ...       ...       ...       ...       ...
# MOAR012_BC3C_24H:P20  0.529700  0.383225 -0.207225  2.268450 -1.248500
# MOAR012_BC3C_24H:P21  0.076499  0.201825  0.416875  0.287450 -0.971700
# MOAR012_BC3C_24H:P22  1.486200  0.440325  0.090075 -0.031650 -0.944300
# MOAR012_BC3C_24H:P23 -0.921501  0.044926  0.716076 -0.000900 -1.106700
# MOAR012_BC3C_24H:P24  0.088650 -0.242075  0.195575 -0.038300 -1.149900
#
# [1971 rows x 978 columns]
# Landmark genes in LINCS data: 978 ['AARS', 'ABCB6', 'ABCC5', 'ABCF1', 'ABCF3', 'ABHD4', 'ABHD6', 'ABL1', 'ACAA1', 'ACAT2', 'ACBD3', 'ACD', 'ACLY', 'ACOT9', 'ADAM10', 'ADAT1', 'ADGRE5', 'ADGRG1', 'ADH5', 'ADI1', 'ADO', 'ADRB2', 'AGL', 'AKAP8', 'AKAP8L', 'AKR7A2', 'AKT1', 'ALAS1', 'ALDH7A1', 'ALDOA', 'ALDOC', 'AMDHD2', 'ANKRD10', 'ANO10', 'ANXA7', 'APBB2', 'APOE', 'APP', 'APPBP2', 'ARFIP2', 'ARHGAP1', 'ARHGEF12', 'ARHGEF2', 'ARID4B', 'ARID5B', 'ARL4C', 'ARNT2', 'ARPP19', 'ASAH1', 'ASCC3', 'ATF1', 'ATF5', 'ATF6', 'ATG3', 'ATMIN', 'ATP11B', 'ATP1B1', 'ATP2C1', 'ATP6V0B', 'ATP6V1D', 'AURKA', 'AURKB', 'AXIN1', 'B4GAT1', 'BACE2', 'BAD', 'BAG3', 'BAMBI', 'BAX', 'BCL2', 'BCL7B', 'BDH1', 'BECN1', 'BHLHE40', 'BID', 'BIRC2', 'BIRC5', 'BLCAP', 'BLMH', 'BLVRA', 'BMP4', 'BNIP3', 'BNIP3L', 'BPHL', 'BRCA1', 'BTK', 'BUB1B', 'BZW2', 'C2CD2', 'C2CD2L', 'C2CD5', 'C5', 'CAB39', 'CALM3', 'CALU', 'CAMSAP2', 'CANT1', 'CAPN1', 'CARMIL1', 'CASC3', 'CASK', 'CASP10', 'CASP2', 'CASP3', 'CASP7', 'CAST', 'CAT', 'CBLB', 'CBR1', 'CBR3', 'CCDC85B', 'CCDC86', 'CCDC92', 'CCL2', 'CCNA1', 'CCNA2', 'CCNB1', 'CCNB2', 'CCND1', 'CCND3', 'CCNE2', 'CCNF', 'CCNH', 'CCP110', 'CD320', 'CD40', 'CD44', 'CD58', 'CDC20', 'CDC25A', 'CDC25B', 'CDC42', 'CDC45', 'CDCA4', 'CDH3', 'CDK1', 'CDK19', 'CDK2', 'CDK4', 'CDK5R1', 'CDK6', 'CDK7', 'CDKN1A', 'CDKN1B', 'CDKN2A', 'CEBPA', 'CEBPD', 'CEBPZ', 'CEMIP2', 'CENPE', 'CEP57', 'CERK', 'CETN3', 'CFLAR', 'CGRRF1', 'CHAC1', 'CHEK1', 'CHEK2', 'CHERP', 'CHIC2', 'CHMP4A', 'CHMP6', 'CHN1', 'CHP1', 'CIAO3', 'CIAPIN1', 'CIRBP', 'CISD1', 'CLIC4', 'CLPX', 'CLSTN1', 'CLTB', 'CLTC', 'CNDP2', 'CNOT4', 'CNPY3', 'COASY', 'COG2', 'COG4', 'COG7', 'COL1A1', 'COL4A1', 'COPB2', 'COPS7A', 'COQ8A', 'CORO1A', 'CPNE3', 'CPSF4', 'CREB1', 'CREG1', 'CRELD2', 'CRK', 'CRKL', 'CRTAP', 'CRYZ', 'CSK', 'CSNK1A1', 'CSNK1E', 'CSNK2A2', 'CSRP1', 'CTNNAL1', 'CTNND1', 'CTSD', 'CTSL', 'CTTN', 'CXCL2', 'CXCR4', 'CYB561', 'CYCS', 'CYTH1', 'DAG1', 'DAXX', 'DCK', 'DCTD', 'DCUN1D4', 'DDB2', 'DDIT4', 'DDR1', 'DDX10', 'DDX42', 'DECR1', 'DENND2D', 'DERA', 'DFFA', 'DFFB', 'DHDDS', 'DHRS7', 'DHX29', 'DIPK1A', 'DLD', 'DMAC2L', 'DMTF1', 'DNAJA3', 'DNAJB1', 'DNAJB2', 'DNAJB6', 'DNAJC15', 'DNM1', 'DNM1L', 'DNMT1', 'DNMT3A', 'DNTTIP2', 'DPH2', 'DRAP1', 'DSG2', 'DUSP11', 'DUSP14', 'DUSP22', 'DUSP3', 'DUSP4', 'DUSP6', 'DYNLT3', 'DYRK3', 'E2F2', 'EAPP', 'EBNA1BP2', 'EBP', 'ECD', 'ECH1', 'EDEM1', 'EDN1', 'EED', 'EFCAB14', 'EGF', 'EGFR', 'EGR1', 'EIF4EBP1', 'EIF4G1', 'EIF5', 'ELAC2', 'ELAVL1', 'ELOVL6', 'ELP1', 'EML3', 'ENOPH1', 'ENOSF1', 'EPB41L2', 'EPHA3', 'EPHB2', 'EPN2', 'EPRS', 'ERBB2', 'ERBB3', 'ERO1A', 'ETFB', 'ETS1', 'ETV1', 'EVL', 'EXOSC4', 'EXT1', 'EZH2', 'FAH', 'FAIM', 'FAM20B', 'FAM57A', 'FAS', 'FASTKD5', 'FAT1', 'FBXL12', 'FBXO11', 'FBXO21', 'FBXO7', 'FCHO1', 'FDFT1', 'FEZ2', 'FGFR2', 'FGFR4', 'FHL2', 'FIS1', 'FKBP14', 'FKBP4', 'FOS', 'FOSL1', 'FOXJ3', 'FOXO3', 'FOXO4', 'FPGS', 'FRS2', 'FSD1', 'FUT1', 'FYN', 'FZD1', 'FZD7', 'G3BP1', 'GAA', 'GABPB1', 'GADD45A', 'GADD45B', 'GALE', 'GAPDH', 'GATA2', 'GATA3', 'GDPD5', 'GFOD1', 'GFPT1', 'GHR', 'GLI2', 'GLOD4', 'GLRX', 'GMNN', 'GNA11', 'GNA15', 'GNAI1', 'GNAI2', 'GNAS', 'GNB5', 'GNPDA1', 'GOLT1B', 'GPATCH8', 'GPC1', 'GPER1', 'GRB10', 'GRB7', 'GRN', 'GRWD1', 'GSTM2', 'GSTZ1', 'GTF2A2', 'GTF2E2', 'GTPBP8', 'H2AFV', 'HACD3', 'HADH', 'HAT1', 'HDAC2', 'HDAC6', 'HDGFL3', 'HEATR1', 'HEBP1', 'HERC6', 'HERPUD1', 'HES1', 'HIF1A', 'HIST1H2BK', 'HIST2H2BE', 'HK1', 'HLA-DMA', 'HLA-DRA', 'HMG20B', 'HMGA2', 'HMGCR', 'HMGCS1', 'HMOX1', 'HOMER2', 'HOOK2', 'HOXA10', 'HOXA5', 'HPRT1', 'HS2ST1', 'HSD17B10', 'HSD17B11', 'HSPA1A', 'HSPA4', 'HSPA8', 'HSPB1', 'HSPD1', 'HTATSF1', 'HTRA1', 'HYOU1', 'IARS2', 'ICAM1', 'ICAM3', 'ICMT', 'ID2', 'IDE', 'IER3', 'IFNAR1', 'IFRD2', 'IGF1R', 'IGF2BP2', 'IGF2R', 'IGFBP3', 'IGHMBP2', 'IKBKB', 'IKBKE', 'IKZF1', 'IL13RA1', 'IL1B', 'IL4R', 'ILK', 'INPP1', 'INPP4B', 'INSIG1', 'INTS3', 'IPO13', 'IQGAP1', 'ISOC1', 'ITFG1', 'ITGAE', 'ITGB1BP1', 'ITGB5', 'JADE2', 'JMJD6', 'JPT2', 'JUN', 'KAT6A', 'KAT6B', 'KCNK1', 'KCTD5', 'KDELR2', 'KD ...
# Experiments in LINCS data for BC3C cells: 1971 ['ASG002_BC3C_24H:A03', 'ASG002_BC3C_24H:A04', 'ASG002_BC3C_24H:A05', 'ASG002_BC3C_24H:A06', 'ASG002_BC3C_24H:J13', 'ASG002_BC3C_24H:J14', 'ASG002_BC3C_24H:J15', 'ASG002_BC3C_24H:J16', 'ASG002_BC3C_24H:J17', 'ASG002_BC3C_24H:J18', 'ASG002_BC3C_24H:O04', 'ASG002_BC3C_24H:O05', 'ASG002_BC3C_24H:O06', 'MOAR008_BC3C_24H:A03', 'MOAR008_BC3C_24H:B03', 'MOAR009_BC3C_24H:A03', 'MOAR009_BC3C_24H:B03', 'MOAR010_BC3C_24H:A03', 'MOAR010_BC3C_24H:B03', 'MOAR010_BC3C_24H:C22', 'MOAR010_BC3C_24H:C23', 'MOAR010_BC3C_24H:C24', 'MOAR010_BC3C_24H:G16', 'MOAR010_BC3C_24H:G17', 'MOAR010_BC3C_24H:G18', 'MOAR010_BC3C_24H:K10', 'MOAR010_BC3C_24H:K11', 'MOAR010_BC3C_24H:K12', 'MOAR010_BC3C_24H:O04', 'MOAR010_BC3C_24H:O05', 'MOAR010_BC3C_24H:O06', 'MOAR011_BC3C_24H:A03', 'MOAR011_BC3C_24H:B03', 'MOAR012_BC3C_24H:A03', 'MOAR012_BC3C_24H:B03', 'ASG002_BC3C_24H:A07', 'ASG002_BC3C_24H:A08', 'ASG002_BC3C_24H:A09', 'ASG002_BC3C_24H:A10', 'ASG002_BC3C_24H:A11', 'ASG002_BC3C_24H:A13', 'ASG002_BC3C_24H:A14', 'ASG002_BC3C_24H:A15', 'ASG002_BC3C_24H:A16', 'ASG002_BC3C_24H:A17', 'ASG002_BC3C_24H:A18', 'ASG002_BC3C_24H:A19', 'ASG002_BC3C_24H:A20', 'ASG002_BC3C_24H:A21', 'ASG002_BC3C_24H:A22', 'ASG002_BC3C_24H:A23', 'ASG002_BC3C_24H:A24', 'ASG002_BC3C_24H:B04', 'ASG002_BC3C_24H:B05', 'ASG002_BC3C_24H:B06', 'ASG002_BC3C_24H:B07', 'ASG002_BC3C_24H:B08', 'ASG002_BC3C_24H:B09', 'ASG002_BC3C_24H:B10', 'ASG002_BC3C_24H:B11', 'ASG002_BC3C_24H:B12', 'ASG002_BC3C_24H:B14', 'ASG002_BC3C_24H:B15', 'ASG002_BC3C_24H:B16', 'ASG002_BC3C_24H:B17', 'ASG002_BC3C_24H:B18', 'ASG002_BC3C_24H:B19', 'ASG002_BC3C_24H:B20', 'ASG002_BC3C_24H:B21', 'ASG002_BC3C_24H:B22', 'ASG002_BC3C_24H:B23', 'ASG002_BC3C_24H:C01', 'ASG002_BC3C_24H:C03', 'ASG002_BC3C_24H:C04', 'ASG002_BC3C_24H:C05', 'ASG002_BC3C_24H:C06', 'ASG002_BC3C_24H:C07', 'ASG002_BC3C_24H:C08', 'ASG002_BC3C_24H:C09', 'ASG002_BC3C_24H:C10', 'ASG002_BC3C_24H:C11', 'ASG002_BC3C_24H:C12', 'ASG002_BC3C_24H:C13', 'ASG002_BC3C_24H:C14', 'ASG002_BC3C_24H:C15', 'ASG002_BC3C_24H:C16', 'ASG002_BC3C_24H:C17', 'ASG002_BC3C_24H:C18', 'ASG002_BC3C_24H:C20', 'ASG002_BC3C_24H:C21', 'ASG002_BC3C_24H:C23', 'ASG002_BC3C_24H:C24', 'ASG002_BC3C_24H:D01', 'ASG002_BC3C_24H:D02', 'ASG002_BC3C_24H:D03', 'ASG002_BC3C_24H:D04', 'ASG002_BC3C_24H:D05', 'ASG002_BC3C_24H:D06', 'ASG002_BC3C_24H:D07', 'ASG002_BC3C_24H:D08', 'ASG002_BC3C_24H:D09', 'ASG002_BC3C_24H:D10', 'ASG002_BC3C_24H:D11', 'ASG002_BC3C_24H:D12', 'ASG002_BC3C_24H:D14', 'ASG002_BC3C_24H:D15', 'ASG002_BC3C_24H:D16', 'ASG002_BC3C_24H:D17', 'ASG002_BC3C_24H:D18', 'ASG002_BC3C_24H:D19', 'ASG002_BC3C_24H:D20', 'ASG002_BC3C_24H:D21', 'ASG002_BC3C_24H:D22', 'ASG002_BC3C_24H:D23', 'ASG002_BC3C_24H:D24', 'ASG002_BC3C_24H:E01', 'ASG002_BC3C_24H:E02', 'ASG002_BC3C_24H:E04', 'ASG002_BC3C_24H:E05', 'ASG002_BC3C_24H:E06', 'ASG002_BC3C_24H:E09', 'ASG002_BC3C_24H:E10', 'ASG002_BC3C_24H:E11', 'ASG002_BC3C_24H:E13', 'ASG002_BC3C_24H:E14', 'ASG002_BC3C_24H:E15', 'ASG002_BC3C_24H:E16', 'ASG002_BC3C_24H:E17', 'ASG002_BC3C_24H:E18', 'ASG002_BC3C_24H:E19', 'ASG002_BC3C_24H:E20', 'ASG002_BC3C_24H:E21', 'ASG002_BC3C_24H:E22', 'ASG002_BC3C_24H:E23', 'ASG002_BC3C_24H:E24', 'ASG002_BC3C_24H:F01', 'ASG002_BC3C_24H:F02', 'ASG002_BC3C_24H:F03', 'ASG002_BC3C_24H:F04', 'ASG002_BC3C_24H:F05', 'ASG002_BC3C_24H:F06', 'ASG002_BC3C_24H:F07', 'ASG002_BC3C_24H:F08', 'ASG002_BC3C_24H:F09', 'ASG002_BC3C_24H:F10', 'ASG002_BC3C_24H:F11', 'ASG002_BC3C_24H:F13', 'ASG002_BC3C_24H:F14', 'ASG002_BC3C_24H:F15', 'ASG002_BC3C_24H:F16', 'ASG002_BC3C_24H:F17', 'ASG002_BC3C_24H:F18', 'ASG002_BC3C_24H:F19', 'ASG002_BC3C_24H:F20', 'ASG002_BC3C_24H:F21', 'ASG002_BC3C_24H:F22', 'ASG002_BC3C_24H:F23', 'ASG002_BC3C_24H:F24', 'ASG002_BC3C_24H:G01', 'ASG002_BC3C_24H:G02', 'ASG002_BC3C_24H:G03', 'ASG002_BC3C_24H:G04', 'ASG002_BC3C_24H:G05', 'ASG002_BC3C_24H:G06', 'ASG002_BC3C_24H:G07', 'ASG002_BC3C_24H:G09', 'ASG002_BC3C_24H:G10', 'ASG002_BC3C_24H:G12', 'ASG002_BC3C_24H:G13', 'ASG002_BC3C_24H:G14', 'ASG002_BC3C_24H:G15 ...

# %% [markdown]
# ### Sig info

# %%
data_file = os.path.join(data_dir, "sig_info_" + data_year + "_" + cell_name+ ".xlsx")
sig_info_cell_df = pd.read_excel(data_file, index_col = 0).fillna("")
display(sig_info_cell_df)
# Out:
#                       cell    plate  time              level_3_samples  \
# level_5_sig_id
# ASG002_BC3C_24H:A03   BC3C   ASG002  24 h   ASG002_BC3C_24H_X1_B35:A03
# ASG002_BC3C_24H:A04   BC3C   ASG002  24 h   ASG002_BC3C_24H_X1_B35:A04
# ASG002_BC3C_24H:A05   BC3C   ASG002  24 h   ASG002_BC3C_24H_X1_B35:A05
# ASG002_BC3C_24H:A06   BC3C   ASG002  24 h   ASG002_BC3C_24H_X1_B35:A06
# ASG002_BC3C_24H:J13   BC3C   ASG002  24 h   ASG002_BC3C_24H_X1_B35:J13
# ...                    ...      ...   ...                          ...
# MOAR012_BC3C_24H:P20  BC3C  MOAR012  24 h  MOAR012_BC3C_24H_X1_B36:P20
# MOAR012_BC3C_24H:P21  BC3C  MOAR012  24 h  MOAR012_BC3C_24H_X1_B36:P21
# MOAR012_BC3C_24H:P22  BC3C  MOAR012  24 h  MOAR012_BC3C_24H_X1_B36:P22
# MOAR012_BC3C_24H:P23  BC3C  MOAR012  24 h  MOAR012_BC3C_24H_X1_B36:P23
# MOAR012_BC3C_24H:P24  BC3C  MOAR012  24 h  MOAR012_BC3C_24H_X1_B36:P24
#
#                       samples_number    pert_type    pert_drug  \
# level_5_sig_id
# ASG002_BC3C_24H:A03                1  ctl_vehicle         DMSO
# ASG002_BC3C_24H:A04                1  ctl_vehicle         DMSO
# ASG002_BC3C_24H:A05                1  ctl_vehicle         DMSO
# ASG002_BC3C_24H:A06                1  ctl_vehicle         DMSO
# ASG002_BC3C_24H:J13                1  ctl_vehicle         DMSO
# ...                              ...          ...          ...
# MOAR012_BC3C_24H:P20               1       trt_cp  BAY-61-3606
# MOAR012_BC3C_24H:P21               1       trt_cp  BAY-61-3606
# MOAR012_BC3C_24H:P22               1       trt_cp   ethaverine
# MOAR012_BC3C_24H:P23               1       trt_cp   ethaverine
# MOAR012_BC3C_24H:P24               1       trt_cp   ethaverine
#
#                              targets  targets_number     dose  dose_float
# level_5_sig_id
# ASG002_BC3C_24H:A03   DMSO_No_target               0     0 uM        0.00
# ASG002_BC3C_24H:A04   DMSO_No_target               0     0 uM        0.00
# ASG002_BC3C_24H:A05   DMSO_No_target               0     0 uM        0.00
# ASG002_BC3C_24H:A06   DMSO_No_target               0     0 uM        0.00
# ASG002_BC3C_24H:J13   DMSO_No_target               0     0 uM        0.00
# ...                              ...             ...      ...         ...
# MOAR012_BC3C_24H:P20                               0  3.33 uM        3.33
# MOAR012_BC3C_24H:P21                               0  1.11 uM        1.11
# MOAR012_BC3C_24H:P22                               0    10 uM       10.00
# MOAR012_BC3C_24H:P23                               0  3.33 uM        3.33
# MOAR012_BC3C_24H:P24                               0  1.11 uM        1.11
#
# [1971 rows x 11 columns]

# %% [markdown]
# ### Read DPDs

# %%
# load STV data frame
STVs = pd.read_excel(os.path.join(data_dir, "ALL_DATA_2020_Jing.xlsx"), sheet_name = "STV", index_col = 0)

states = STVs.columns.to_list()
print("States:", states)

STV_df = pd.DataFrame(
    np.zeros((len(genes_list), len(states))), 
    index = genes_list, 
    columns = states)

STV_df.loc[STVs.index] = STVs

display(STV_df)

DPD_df = pd.DataFrame(
    np.zeros((len(exp_id_list), len(states))),
    index = exp_id_list,
    columns = states,
)
# Out:
# States: ['blca_invasiveness', 'blca_oncogenesis', 'blca_survival']
#         blca_invasiveness  blca_oncogenesis  blca_survival
# AARS             0.016052          0.078487       0.000000
# ABCB6            0.001612          0.027125      -2.890931
# ABCC5           -0.016742          0.002121       0.000000
# ABCF1           -0.038990         -0.028959      -0.496186
# ABCF3            0.023288          0.036671       0.000000
# ...                   ...               ...            ...
# ZNF395           0.000000          0.000000       0.000000
# ZNF451           0.011450          0.013403       0.000000
# ZNF586           0.000000          0.000000       0.119103
# ZNF589           0.000000          0.000000       0.000000
# ZW10            -0.042841          0.009722       0.000000
#
# [978 rows x 3 columns]

# %%
DPD_df = pd.DataFrame(
    np.zeros((len(exp_id_list), len(states))),
    index = exp_id_list,
    columns = states,
)
for exp_id in DPD_df.index:
    DPD_df.loc[exp_id] = np.dot(Data_norm.loc[exp_id], STV_df.loc[:, ])

display(DPD_df)
# Out:
#                       blca_invasiveness  blca_oncogenesis  blca_survival
# ASG002_BC3C_24H:A03            0.224169          0.302763      -2.655867
# ASG002_BC3C_24H:A04            0.150151         -0.135368      -3.584228
# ASG002_BC3C_24H:A05            0.167952         -0.014359      -2.363371
# ASG002_BC3C_24H:A06            0.328579         -0.094210      -7.807932
# ASG002_BC3C_24H:J13           -0.582389         -0.243571       0.562112
# ...                                 ...               ...            ...
# MOAR012_BC3C_24H:P20           1.639600         -0.777955       2.656299
# MOAR012_BC3C_24H:P21           0.843686         -0.200156       0.350116
# MOAR012_BC3C_24H:P22           0.530906          0.472079      -3.075259
# MOAR012_BC3C_24H:P23           0.684520         -0.052636      -8.261984
# MOAR012_BC3C_24H:P24          -0.184652          0.325686     -22.977586
#
# [1971 rows x 3 columns]

# %%
#Full info
data_norm_info_df = pd.concat([Data_norm,
                               sig_info_cell_df.loc[Data_norm.index,['pert_drug','targets','dose','dose_float']]],
                               axis=1)                            
display(data_norm_info_df)
# Out:
#                           AARS     ABCB6     ABCC5     ABCF1     ABCF3  \
# ASG002_BC3C_24H:A03  -0.191254 -0.055246  0.039596 -0.256266 -0.040419
# ASG002_BC3C_24H:A04  -0.265754 -0.317496  0.118696 -0.136665 -0.301569
# ASG002_BC3C_24H:A05  -0.181954 -0.081597 -0.210304  1.559535 -0.019019
# ASG002_BC3C_24H:A06   0.033446  0.042404 -0.150154 -0.093165  0.053180
# ASG002_BC3C_24H:J13   0.204446  0.180704  0.089096 -0.054666  0.053381
# ...                        ...       ...       ...       ...       ...
# MOAR012_BC3C_24H:P20  0.647151  0.211700 -0.979200  0.597350 -0.375751
# MOAR012_BC3C_24H:P21  0.171800  0.046300 -0.145550 -0.295150  0.030849
# MOAR012_BC3C_24H:P22  0.648700  0.058749 -0.031700  0.408249 -0.753950
# MOAR012_BC3C_24H:P23  0.090499 -0.469300 -0.611800  0.873550 -0.788450
# MOAR012_BC3C_24H:P24  0.204801 -1.388700 -0.283400  0.744750 -1.431150
#
#                          ABHD4     ABHD6      ABL1     ACAA1     ACAT2  ...  \
# ASG002_BC3C_24H:A03  -0.590523 -0.159396 -0.074319  0.457981  0.409608  ...
# ASG002_BC3C_24H:A04  -0.403023  0.124804 -0.036470  0.311931  0.660457  ...
# ASG002_BC3C_24H:A05  -0.457423  0.071404  0.074080 -0.356119  0.498808  ...
# ASG002_BC3C_24H:A06  -0.053823  0.087704  0.167681 -0.601569  0.383308  ...
# ASG002_BC3C_24H:J13   0.044877 -0.277396 -0.157419  0.535681 -3.933493  ...
# ...                        ...       ...       ...       ...       ...  ...
# MOAR012_BC3C_24H:P20  0.388300  0.394524  0.120151 -0.166775 -1.129125  ...
# MOAR012_BC3C_24H:P21  0.420951  0.222075  0.179800  0.274724 -0.423975  ...
# MOAR012_BC3C_24H:P22  0.332200 -0.357525 -0.107650 -0.213575  0.074225  ...
# MOAR012_BC3C_24H:P23 -0.097199 -0.366575 -0.490600 -0.624675 -0.009275  ...
# MOAR012_BC3C_24H:P24 -0.518100 -0.002174 -0.096200  1.198824  0.138525  ...
#
#                         ZNF318    ZNF395    ZNF451    ZNF586    ZNF589  \
# ASG002_BC3C_24H:A03   0.285054 -0.775246  0.166031 -0.024873  0.238723
# ASG002_BC3C_24H:A04   0.141804  0.129054 -0.028819 -0.028773 -0.253627
# ASG002_BC3C_24H:A05  -0.133146  0.355054  0.022831 -0.084073  0.283123
# ASG002_BC3C_24H:A06  -0.570996  2.847754 -0.211670 -0.067273  0.081723
# ASG002_BC3C_24H:J13  -0.067996 -0.515847 -0.005069  0.067527  0.002223
# ...                        ...       ...       ...       ...       ...
# MOAR012_BC3C_24H:P20  0.082675  0.529700  0.383225 -0.207225  2.268450
# MOAR012_BC3C_24H:P21 -0.037675  0.076499  0.201825  0.416875  0.287450
# MOAR012_BC3C_24H:P22  0.046375  1.486200  0.440325  0.090075 -0.031650
# MOAR012_BC3C_24H:P23  0.431375 -0.921501  0.044926  0.716076 -0.000900
# MOAR012_BC3C_24H:P24 -0.259925  0.088650 -0.242075  0.195575 -0.038300
#
#                           ZW10    pert_drug         targets     dose  \
# ASG002_BC3C_24H:A03   0.284204         DMSO  DMSO_No_target     0 uM
# ASG002_BC3C_24H:A04  -0.752646         DMSO  DMSO_No_target     0 uM
# ASG002_BC3C_24H:A05  -0.894896         DMSO  DMSO_No_target     0 uM
# ASG002_BC3C_24H:A06   0.338704         DMSO  DMSO_No_target     0 uM
# ASG002_BC3C_24H:J13   0.204904         DMSO  DMSO_No_target     0 uM
# ...                        ...          ...             ...      ...
# MOAR012_BC3C_24H:P20 -1.248500  BAY-61-3606                  3.33 uM
# MOAR012_BC3C_24H:P21 -0.971700  BAY-61-3606                  1.11 uM
# MOAR012_BC3C_24H:P22 -0.944300   ethaverine                    10 uM
# MOAR012_BC3C_24H:P23 -1.106700   ethaverine                  3.33 uM
# MOAR012_BC3C_24H:P24 -1.149900   ethaverine                  1.11 uM
#
#                       dose_float
# ASG002_BC3C_24H:A03         0.00
# ASG002_BC3C_24H:A04         0.00
# ASG002_BC3C_24H:A05         0.00
# ASG002_BC3C_24H:A06         0.00
# ASG002_BC3C_24H:J13         0.00
# ...                          ...
# MOAR012_BC3C_24H:P20        3.33
# MOAR012_BC3C_24H:P21        1.11
# MOAR012_BC3C_24H:P22       10.00
# MOAR012_BC3C_24H:P23        3.33
# MOAR012_BC3C_24H:P24        1.11
#
# [1971 rows x 982 columns]

# %%
ids = []

# %% [markdown]
# ### Targets

# %%
#targets 'TOP2A'

# %%
target = 'AR'
to_pca_df=data_norm_info_df.loc[data_norm_info_df.targets.str.contains(f'{target}')]
set(to_pca_df['pert_drug'])
# Out:
# {'4-IBP',
#  'AG-14361',
#  'AM-580',
#  'API-001',
#  'BD-1063',
#  'GW-501516',
#  'L-693403',
#  'PRE-084',
#  'cutamesine',
#  'etofylline-clofibrate',
#  'flufenamic-acid',
#  'nandrolone',
#  'olaparib',
#  'oleoylethanolamide',
#  'oxandrolone',
#  'rimcazole',
#  'rucaparib',
#  'tamibarotene',
#  'testosterone-enanthate',
#  'testosterone-propionate',
#  'troglitazone'}

# %%
to_pca_df = data_norm_info_df.loc[
    data_norm_info_df.pert_drug.isin(['testosterone-enanthate',
 'testosterone-propionate','oxandrolone','nandrolone', 'flufenamic-acid'])]

display(to_pca_df)
# Out:
#                           AARS     ABCB6     ABCC5     ABCF1     ABCF3  \
# MOAR008_BC3C_24H:L01  0.154250 -0.304076 -0.127625 -1.180562  0.266649
# MOAR008_BC3C_24H:L02  0.301575 -0.168951 -0.194825  0.183737  0.045850
# MOAR008_BC3C_24H:L03 -0.059750  0.370149 -0.069300  0.684488 -0.311650
# MOAR010_BC3C_24H:L19 -0.074268 -0.003798  0.187043  1.132361 -0.028568
# MOAR010_BC3C_24H:L20 -0.012317 -0.661323 -0.051357 -0.555990  0.447982
# MOAR010_BC3C_24H:L21 -0.004018  0.326502  0.358943 -0.556689  0.610582
# MOAR011_BC3C_24H:C01  0.215100  0.127850  0.197500 -0.036825 -0.378251
# MOAR011_BC3C_24H:C02 -0.178100  0.081150  0.119350 -0.080325  0.003950
# MOAR011_BC3C_24H:C03 -0.007000 -0.026850  0.212450  0.059175  0.127300
# MOAR011_BC3C_24H:C10  0.024000 -0.152851 -0.177250  0.307175 -0.197401
# MOAR011_BC3C_24H:C11  0.007400  0.122550  0.138650  0.580075 -0.128351
# MOAR011_BC3C_24H:J10  0.031399 -0.029350  0.568950  0.322875 -0.012850
#
#                          ABHD4     ABHD6      ABL1     ACAA1     ACAT2  ...  \
# MOAR008_BC3C_24H:L01 -0.050400  0.056025 -0.881976  1.474024 -0.015975  ...
# MOAR008_BC3C_24H:L02 -0.234051  0.128175  0.138249 -0.283675 -0.769725  ...
# MOAR008_BC3C_24H:L03 -0.186050  0.138075  0.490900  0.867400  0.122625  ...
# MOAR010_BC3C_24H:L19  0.603684 -0.328418  0.675770  0.363604 -0.250681  ...
# MOAR010_BC3C_24H:L20  0.560984 -0.457968 -0.557531  0.887504  0.145620  ...
# MOAR010_BC3C_24H:L21  0.600735 -0.329518 -0.286781  1.313554 -0.015581  ...
# MOAR011_BC3C_24H:C01 -0.120650  0.202800  0.129700  0.020975 -0.118250  ...
# MOAR011_BC3C_24H:C02 -0.174251  0.060000 -0.007400  0.168475 -0.174450  ...
# MOAR011_BC3C_24H:C03  0.265550  0.207500 -0.017300 -0.057625 -0.117950  ...
# MOAR011_BC3C_24H:C10 -0.391351 -0.016400 -0.308050  1.001475 -0.338650  ...
# MOAR011_BC3C_24H:C11 -0.255150  0.499500  0.056400  0.174625 -0.289650  ...
# MOAR011_BC3C_24H:J10  0.022250 -0.039200  0.393200  0.025475 -0.224650  ...
#
#                         ZNF318    ZNF395    ZNF451    ZNF586    ZNF589  \
# MOAR008_BC3C_24H:L01 -0.609487  0.163900 -0.139087 -0.003450 -0.132325
# MOAR008_BC3C_24H:L02 -0.417787  0.702250 -0.067338  0.257350 -0.399200
# MOAR008_BC3C_24H:L03 -0.292437  0.115351  0.138862  0.053500 -0.405850
# MOAR010_BC3C_24H:L19  0.092396 -1.188080  0.107632 -0.005365 -0.027441
# MOAR010_BC3C_24H:L20  0.147146 -0.050680 -0.083718 -0.123664  0.007359
# MOAR010_BC3C_24H:L21  0.293196 -1.175880  0.105732 -0.191564 -0.072891
# MOAR011_BC3C_24H:C01  0.448500  0.300250 -0.324500 -0.304650 -0.315500
# MOAR011_BC3C_24H:C02  0.083450 -0.265350  0.080550 -0.259400 -0.013900
# MOAR011_BC3C_24H:C03  0.121450 -0.380850 -0.114950  0.163600 -0.035050
# MOAR011_BC3C_24H:C10  0.483050 -0.330950 -0.337650 -0.428700  1.836400
# MOAR011_BC3C_24H:C11  0.158450 -1.844650 -0.024950 -0.069200 -0.223300
# MOAR011_BC3C_24H:J10  0.208650 -0.612350 -0.151550  0.073700 -0.343400
#
#                           ZW10                pert_drug  \
# MOAR008_BC3C_24H:L01 -0.031200          flufenamic-acid
# MOAR008_BC3C_24H:L02 -0.800000          flufenamic-acid
# MOAR008_BC3C_24H:L03 -0.603100          flufenamic-acid
# MOAR010_BC3C_24H:L19 -0.014018  testosterone-propionate
# MOAR010_BC3C_24H:L20  0.211432  testosterone-propionate
# MOAR010_BC3C_24H:L21 -0.360368  testosterone-propionate
# MOAR011_BC3C_24H:C01 -0.142150              oxandrolone
# MOAR011_BC3C_24H:C02  0.443400              oxandrolone
# MOAR011_BC3C_24H:C03 -0.145650              oxandrolone
# MOAR011_BC3C_24H:C10  0.433800   testosterone-enanthate
# MOAR011_BC3C_24H:C11  0.048100   testosterone-enanthate
# MOAR011_BC3C_24H:J10  0.049950               nandrolone
#
#                                              targets     dose  dose_float
# MOAR008_BC3C_24H:L01        AKR1C3, AR, PTGS1, PTGS2    10 uM       10.00
# MOAR008_BC3C_24H:L02        AKR1C3, AR, PTGS1, PTGS2  3.33 uM        3.33
# MOAR008_BC3C_24H:L03        AKR1C3, AR, PTGS1, PTGS2  1.11 uM        1.11
# MOAR010_BC3C_24H:L19                              AR    10 uM       10.00
# MOAR010_BC3C_24H:L20                              AR  3.33 uM        3.33
# MOAR010_BC3C_24H:L21                              AR  1.11 uM        1.11
# MOAR011_BC3C_24H:C01                              AR    10 uM       10.00
# MOAR011_BC3C_24H:C02                              AR  3.33 uM        3.33
# MOAR011_BC3C_24H:C03                              AR  1.11 uM        1.11
# MOAR011_BC3C_24H:C10                              AR    10 uM       10.00
# MOAR011_BC3C_24H:C11                              AR  3.33 uM        3.33
# MOAR011_BC3C_24H:J10  AR, CYP19A1, MAOA, MAOB, NISCH    10 uM       10.00
#
# [12 rows x 982 columns]

# %%
to_pca_dpds =DPD_df.loc[to_pca_df.index,['blca_invasiveness', 'blca_oncogenesis', 'blca_survival']]
display(to_pca_dpds)
# Out:
#                       blca_invasiveness  blca_oncogenesis  blca_survival
# MOAR008_BC3C_24H:L01           0.237716         -0.180035      16.915005
# MOAR008_BC3C_24H:L02           0.426218          0.025146      -2.128777
# MOAR008_BC3C_24H:L03          -1.038098          0.499069      -8.491014
# MOAR010_BC3C_24H:L19          -0.257099          0.295985       7.883618
# MOAR010_BC3C_24H:L20           0.209265          0.000975      15.021023
# MOAR010_BC3C_24H:L21          -0.853594          0.785934      11.324876
# MOAR011_BC3C_24H:C01           0.294934          0.039863       7.548515
# MOAR011_BC3C_24H:C02           0.513808          0.106842       1.064820
# MOAR011_BC3C_24H:C03           0.320511         -0.068887       5.703725
# MOAR011_BC3C_24H:C10           0.401778         -0.875167       9.754974
# MOAR011_BC3C_24H:C11           0.426267         -0.261326      -4.383434
# MOAR011_BC3C_24H:J10           0.992079         -0.115337       5.555040

# %%
scaled_data = sklearn.preprocessing.StandardScaler().fit_transform(to_pca_dpds.values)
model = sklearn.decomposition.PCA(n_components=2)
new = model.fit_transform(scaled_data)
explained = model.explained_variance_ratio_
print(explained)
# Out:
# [0.5889948  0.31560169]

# %%
result_pca = pd.DataFrame(new,index=to_pca_dpds.index,columns=['PCA1','PCA2'])
result_pca['pert_drug']=to_pca_df.loc[to_pca_dpds.index,'pert_drug']
result_pca['dose']=to_pca_df.loc[to_pca_dpds.index,'dose']
result_pca
# Out:
#                           PCA1      PCA2                pert_drug     dose
# MOAR008_BC3C_24H:L01 -0.868583  1.378477          flufenamic-acid    10 uM
# MOAR008_BC3C_24H:L02 -0.080652 -1.098318          flufenamic-acid  3.33 uM
# MOAR008_BC3C_24H:L03  2.764151 -1.205268          flufenamic-acid  1.11 uM
# MOAR010_BC3C_24H:L19  0.883603  0.570822  testosterone-propionate    10 uM
# MOAR010_BC3C_24H:L20 -0.451548  1.214893  testosterone-propionate  3.33 uM
# MOAR010_BC3C_24H:L21  2.352336  1.437993  testosterone-propionate  1.11 uM
# MOAR011_BC3C_24H:C01 -0.229498  0.221782              oxandrolone    10 uM
# MOAR011_BC3C_24H:C02 -0.155961 -0.678859              oxandrolone  3.33 uM
# MOAR011_BC3C_24H:C03 -0.387029 -0.073340              oxandrolone  1.11 uM
# MOAR011_BC3C_24H:C10 -2.036840  0.097987   testosterone-enanthate    10 uM
# MOAR011_BC3C_24H:C11 -0.503393 -1.510384   testosterone-enanthate  3.33 uM
# MOAR011_BC3C_24H:J10 -1.286586 -0.355785               nandrolone    10 uM

# %%
# Generate a list of unique drugs
unique_drugs = list(set(result_pca['pert_drug']))
# Define color names
color_names = ['red', 'green', 'purple', 'orange', 'blue','brown',  'cyan', 'magenta', 'yellow', 'black', 'gray', 'olive', 'pink', 'lime', 'gold', 'navy', 'maroon', 'teal', 'coral', 'aqua']
colors = plt.cm.tab20.colors  # You can use other colormap as well
num_colors = len(colors)

# %%
# Create a dictionary to map each unique drug to a color
drug_color_map = {drug: color_names[i % len(color_names)] for i, drug in enumerate(unique_drugs)}

# Assign colors to the_colors list based on the drug_color_map
the_colors = [drug_color_map[drug] for drug in result_pca['pert_drug']]

# Define marker sizes based on dose
dose_size_map = {
    '0 uM': 100,
    '0.08 uM': 150,
    '0.12 uM': 250,
    '1.11 uM': 500,
    '3.33 uM': 750,
    '10 uM': 900  # default size for doses not specified
}

# Assign sizes to the marker_sizes list based on the dose_size_map
marker_sizes = [dose_size_map.get(dose, dose_size_map) for dose in result_pca['dose']]

# Define marker shapes
marker_shapes = ['*','s', 'o', 'p', 'd', 'x', ]#, 's', '<', '>', 'v', 'H', '8']
drug_shape_map = {drug: marker_shapes[i % len(marker_shapes)] for i, drug in enumerate(unique_drugs)}

# Assign shapes to the marker_shapes list based on the drug_shape_map
the_shapes = [drug_shape_map[drug] for drug in result_pca['pert_drug']]

# Print the assigned results for verification
for element, color, size, shape in zip(result_pca['pert_drug'], the_colors, marker_sizes, the_shapes):
    print(f"Drug: {element}, Assigned Color: {color}, Size: {size}, Shape: {shape}")
# Out:
# Drug: flufenamic-acid, Assigned Color: blue, Size: 900, Shape: d
# Drug: flufenamic-acid, Assigned Color: blue, Size: 750, Shape: d
# Drug: flufenamic-acid, Assigned Color: blue, Size: 500, Shape: d
# Drug: testosterone-propionate, Assigned Color: purple, Size: 900, Shape: o
# Drug: testosterone-propionate, Assigned Color: purple, Size: 750, Shape: o
# Drug: testosterone-propionate, Assigned Color: purple, Size: 500, Shape: o
# Drug: oxandrolone, Assigned Color: green, Size: 900, Shape: s
# Drug: oxandrolone, Assigned Color: green, Size: 750, Shape: s
# Drug: oxandrolone, Assigned Color: green, Size: 500, Shape: s
# Drug: testosterone-enanthate, Assigned Color: orange, Size: 900, Shape: p
# Drug: testosterone-enanthate, Assigned Color: orange, Size: 750, Shape: p
# Drug: nandrolone, Assigned Color: red, Size: 900, Shape: *

# %%
for i in range(len(result_pca)):
    plt.scatter(result_pca.iloc[i]['PCA1'], result_pca.iloc[i]['PCA2'], s=marker_sizes[i], c=the_colors[i], marker=the_shapes[i], alpha=2/3)
# Create legend
legend_elements = [mpatches.Patch(color=drug_color_map[drug], label=f"{drug} ({drug_color_map[drug]})") for drug in unique_drugs]
plt.legend(handles=legend_elements, title="Drug Colors",ncol=2, bbox_to_anchor=(1.1,1))#

plt.grid(alpha=0.5, ls=':')
plt.title(f'PCA: DPDs of {target} targeted drugs in {cell_name} cell line')
plt.show()

# %%
model=IsolationForest(n_estimators=100,max_samples='auto',contamination=float(0.1),random_state=41)

model.fit(to_pca_dpds)

print(model.get_params())
# Out:
# {'bootstrap': False, 'contamination': 0.1, 'max_features': 1.0, 'max_samples': 'auto', 'n_estimators': 100, 'n_jobs': None, 'random_state': 41, 'verbose': 0, 'warm_start': False}

# %%
result_pca['scores'] = model.decision_function(to_pca_dpds)

result_pca['anomaly_score'] = model.predict(to_pca_dpds)

result_pca[result_pca['anomaly_score']==-1].head()
# Out:
#                           PCA1      PCA2                pert_drug     dose  \
# MOAR008_BC3C_24H:L03  2.764151 -1.205268          flufenamic-acid  1.11 uM
# MOAR010_BC3C_24H:L21  2.352336  1.437993  testosterone-propionate  1.11 uM
#
#                         scores  anomaly_score
# MOAR008_BC3C_24H:L03 -0.043349             -1
# MOAR010_BC3C_24H:L21 -0.005232             -1

# %%
result_pca['targets']=to_pca_df['targets']
result_pca.sort_values(['scores'])
# Out:
#                           PCA1      PCA2                pert_drug     dose  \
# MOAR008_BC3C_24H:L03  2.764151 -1.205268          flufenamic-acid  1.11 uM
# MOAR010_BC3C_24H:L21  2.352336  1.437993  testosterone-propionate  1.11 uM
# MOAR011_BC3C_24H:C10 -2.036840  0.097987   testosterone-enanthate    10 uM
# MOAR011_BC3C_24H:J10 -1.286586 -0.355785               nandrolone    10 uM
# MOAR010_BC3C_24H:L19  0.883603  0.570822  testosterone-propionate    10 uM
# MOAR011_BC3C_24H:C11 -0.503393 -1.510384   testosterone-enanthate  3.33 uM
# MOAR008_BC3C_24H:L01 -0.868583  1.378477          flufenamic-acid    10 uM
# MOAR011_BC3C_24H:C02 -0.155961 -0.678859              oxandrolone  3.33 uM
# MOAR010_BC3C_24H:L20 -0.451548  1.214893  testosterone-propionate  3.33 uM
# MOAR008_BC3C_24H:L02 -0.080652 -1.098318          flufenamic-acid  3.33 uM
# MOAR011_BC3C_24H:C03 -0.387029 -0.073340              oxandrolone  1.11 uM
# MOAR011_BC3C_24H:C01 -0.229498  0.221782              oxandrolone    10 uM
#
#                         scores  anomaly_score                         targets
# MOAR008_BC3C_24H:L03 -0.043349             -1        AKR1C3, AR, PTGS1, PTGS2
# MOAR010_BC3C_24H:L21 -0.005232             -1                              AR
# MOAR011_BC3C_24H:C10  0.047090              1                              AR
# MOAR011_BC3C_24H:J10  0.083051              1  AR, CYP19A1, MAOA, MAOB, NISCH
# MOAR010_BC3C_24H:L19  0.108498              1                              AR
# MOAR011_BC3C_24H:C11  0.115763              1                              AR
# MOAR008_BC3C_24H:L01  0.123825              1        AKR1C3, AR, PTGS1, PTGS2
# MOAR011_BC3C_24H:C02  0.136072              1                              AR
# MOAR010_BC3C_24H:L20  0.153293              1                              AR
# MOAR008_BC3C_24H:L02  0.167152              1        AKR1C3, AR, PTGS1, PTGS2
# MOAR011_BC3C_24H:C03  0.206879              1                              AR
# MOAR011_BC3C_24H:C01  0.208254              1                              AR

# %% [markdown]
# ### ids to be removed

# %%
ids += result_pca[result_pca['anomaly_score'] == -1].index.to_list()

# %%
ids
# Out:
# ['ASG002_BC3C_24H:G01',
#  'ASG002_BC3C_24H:F15',
#  'ASG002_BC3C_24H:N19',
#  'ASG002_BC3C_24H:N22',
#  'ASG002_BC3C_24H:F15',
#  'ASG002_BC3C_24H:I08',
#  'ASG002_BC3C_24H:I19',
#  'ASG002_BC3C_24H:B12',
#  'MOAR008_BC3C_24H:L07',
#  'MOAR008_BC3C_24H:L09',
#  'ASG002_BC3C_24H:F04',
#  'ASG002_BC3C_24H:P17',
#  'ASG002_BC3C_24H:O24',
#  'MOAR010_BC3C_24H:D02',
#  'ASG002_BC3C_24H:L18',
#  'MOAR008_BC3C_24H:L03',
#  'MOAR010_BC3C_24H:L21']

# %%
#result_pca.to_pickle(f"/Users/lidiayung/Downloads/cal29_isf/{cell_name}_{target}_exclusive_PCA_ISF.pkl")

# %%
#result_pca.shape

# %%
set(result_pca['pert_drug'])
# Out:
# {'flufenamic-acid',
#  'nandrolone',
#  'oxandrolone',
#  'testosterone-enanthate',
#  'testosterone-propionate'}
