# %%
import os
import pandas as pd
import numpy as np

import re
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Depmap
blca= pd.read_csv('/home/jing/Phd_project/project_UCD_blca/blca_DATA/blca_DATA_depmep/OmicsExpressionProteinCodingGenesTPMLogp1.csv',index_col=0)
blca.columns = [re.sub(r'\s*\(.*?\)', '', s) for s in list(blca.columns)]
blca
# Out:
#               TSPAN6      TNMD      DPM1     SCYL3  C1orf112       FGR  \
# ACH-001113  4.331992  0.000000  7.364660  2.792855  4.471187  0.028569
# ACH-001289  4.567424  0.584963  7.106641  2.543496  3.504620  0.000000
# ACH-001339  3.150560  0.000000  7.379118  2.333424  4.228049  0.056584
# ACH-001538  5.085340  0.000000  7.154211  2.545968  3.084064  0.000000
# ACH-000242  6.729417  0.000000  6.537917  2.456806  3.867896  0.799087
# ...              ...       ...       ...       ...       ...       ...
# ACH-000285  0.056584  0.000000  6.604368  3.266037  4.973152  0.411426
# ACH-002669  3.111031  0.000000  7.031329  1.541019  3.664483  0.014355
# ACH-001858  4.390943  0.000000  7.013239  1.887525  3.252476  0.028569
# ACH-001997  5.057450  0.000000  7.815191  2.538538  3.893362  0.028569
# ACH-000052  4.249445  0.000000  6.175724  2.319040  3.825786  0.189034
#
#                  CFH     FUCA2      GCLC      NFYA  ...      H3C2      H3C3  \
# ACH-001113  1.226509  3.044394  6.500005  4.739848  ...  2.689299  0.189034
# ACH-001289  0.189034  3.813525  4.221877  3.481557  ...  1.286881  1.049631
# ACH-001339  1.310340  6.687201  3.682573  3.273516  ...  0.594549  1.097611
# ACH-001538  5.868390  6.165309  4.489928  3.956986  ...  0.214125  0.632268
# ACH-000242  7.208478  5.570159  7.127117  4.568032  ...  1.117695  2.358959
# ...              ...       ...       ...       ...  ...       ...       ...
# ACH-000285  0.097611  0.704872  4.829850  5.178715  ...  2.229588  0.084064
# ACH-002669  3.624101  6.805421  4.472488  4.397118  ...  0.189034  0.400538
# ACH-001858  3.286881  6.902194  5.410748  3.401903  ...  1.097611  0.400538
# ACH-001997  4.079805  6.971659  4.469886  3.463361  ...  0.831877  0.847997
# ACH-000052  1.321928  3.538538  3.945795  4.469886  ...  1.244887  1.207893
#
#             AC098582.1  DUS4L-BCAP29  C8orf44-SGK3    ELOA3B    NPBWR1  \
# ACH-001113    0.201634      2.130931      0.555816  0.000000  0.275007
# ACH-001289    0.321928      1.464668      0.632268  0.000000  0.014355
# ACH-001339    0.831877      2.946731      0.475085  0.000000  0.084064
# ACH-001538    0.298658      1.641546      0.443607  0.000000  0.028569
# ACH-000242    0.084064      1.910733      0.000000  0.000000  0.464668
# ...                ...           ...           ...       ...       ...
# ACH-000285    1.310340      3.039138      0.344828  0.000000  0.000000
# ACH-002669    0.356144      1.327687      0.000000  0.000000  0.014355
# ACH-001858    0.613532      1.992768      0.704872  0.000000  1.464668
# ACH-001997    1.292782      2.153805      0.687061  0.000000  0.000000
# ACH-000052    0.000000      1.956057      0.575312  0.042644  0.000000
#
#             ELOA3D     ELOA3      CDR1
# ACH-001113     0.0  0.000000  0.000000
# ACH-001289     0.0  0.000000  0.000000
# ACH-001339     0.0  0.000000  0.042644
# ACH-001538     0.0  0.000000  0.000000
# ACH-000242     0.0  0.000000  0.000000
# ...            ...       ...       ...
# ACH-000285     0.0  0.475085  0.042644
# ACH-002669     0.0  0.000000  0.000000
# ACH-001858     0.0  0.000000  0.526069
# ACH-001997     0.0  0.000000  0.000000
# ACH-000052     0.0  0.176323  0.056584
#
# [1517 rows x 19193 columns]

# %%
cell_lines_all= pd.read_csv('/home/jing/Phd_project/project_UCD_blca/blca_DATA/blca_DATA_depmep/cell lines in Bladder Urothelial Carcinoma.csv')
cell_lines_all
# Out:
#      Depmap Id Cell Line               Primary Disease  Tumor Type
# 0   ACH-000545    VMCUB1  Bladder Urothelial Carcinoma     Primary
# 1   ACH-002235      DSH1  Bladder Urothelial Carcinoma     Primary
# 2   ACH-000384     SW780  Bladder Urothelial Carcinoma     Primary
# 3   ACH-000862     KMBC2  Bladder Urothelial Carcinoma     Primary
# 4   ACH-000834     UMUC1  Bladder Urothelial Carcinoma  Metastatic
# 5   ACH-000593      BC3C  Bladder Urothelial Carcinoma     Primary
# 6   ACH-000547    HT1197  Bladder Urothelial Carcinoma     Primary
# 7   ACH-000142     CAL29  Bladder Urothelial Carcinoma     Primary
# 8   ACH-001183   RT11284  Bladder Urothelial Carcinoma     Primary
# 9   ACH-000486    KU1919  Bladder Urothelial Carcinoma     Primary
# 10  ACH-000018       T24  Bladder Urothelial Carcinoma     Primary
# 11  ACH-001416     UMUC9  Bladder Urothelial Carcinoma     Primary
# 12  ACH-000242       RT4  Bladder Urothelial Carcinoma     Primary
# 13  ACH-000905      5637  Bladder Urothelial Carcinoma     Primary
# 14  ACH-000896      647V  Bladder Urothelial Carcinoma     Primary
# 15  ACH-000522     UMUC3  Bladder Urothelial Carcinoma     Primary
# 16  ACH-000720    TCCSUP  Bladder Urothelial Carcinoma     Primary
# 17  ACH-000802   BFTC905  Bladder Urothelial Carcinoma     Primary
# 18  ACH-001413    UMUC11  Bladder Urothelial Carcinoma     Primary
# 19  ACH-000473     RT112  Bladder Urothelial Carcinoma     Primary
# 20  ACH-001414     UMUC6  Bladder Urothelial Carcinoma     Primary
# 21  ACH-002266  LB831BLC  Bladder Urothelial Carcinoma     Primary
# 22  ACH-000753     JMSU1  Bladder Urothelial Carcinoma  Metastatic
# 23  ACH-001407    UMUC13  Bladder Urothelial Carcinoma  Metastatic
# 24  ACH-001409    UMUC16  Bladder Urothelial Carcinoma     Primary
# 25  ACH-000396       J82  Bladder Urothelial Carcinoma     Primary
# 26  ACH-001410     UMUC4  Bladder Urothelial Carcinoma  Metastatic
# 27  ACH-001415     UMUC7  Bladder Urothelial Carcinoma     Primary
# 28  ACH-000724    HT1376  Bladder Urothelial Carcinoma     Primary
# 29  ACH-000741     UBLC1  Bladder Urothelial Carcinoma     Primary
# 30  ACH-001412    UMUC10  Bladder Urothelial Carcinoma     Primary
# 31  ACH-000026    253JBV  Bladder Urothelial Carcinoma  Metastatic
# 32  ACH-000127     SLR20  Bladder Urothelial Carcinoma     Primary
# 33  ACH-000566    SW1710  Bladder Urothelial Carcinoma     Primary
# 34  ACH-000011      253J  Bladder Urothelial Carcinoma  Metastatic

# %%
cell_lines_all.set_index('Depmap Id',inplace=True)

# %%
scvi_lfc = pd.read_excel('/home/jing/Phd_project/project_UCD_blca/blca_publication_OUTPUT/blca_publication_OUTPUT_svm/blca_scR_scvi_DEG.xlsx',index_col=0)

# %%
scvi_lfc_ta = scvi_lfc.iloc[4000:][['Gene','proba_not_de','lfc_mean']]#n=2000

# %%
scvi_lfc_ta.reset_index(inplace=True)
scvi_lfc_ta.drop(columns=['comparison'],inplace=True)
scvi_lfc_ta.set_index('Gene',inplace=True)
scvi_lfc_ta
# Out:
#            proba_not_de  lfc_mean
# Gene
# UPK1A            0.0294  4.145653
# EPB41L3          0.0384  3.596798
# PHGR1            0.0384  3.159316
# SPOCK1           0.0428  3.138652
# SDC2             0.0632  2.722956
# ...                 ...       ...
# LINC00958        0.0738 -2.434976
# UBE2C            0.0530 -2.450275
# IGKC             0.0554 -2.843966
# DNAJC15          0.0912 -3.190035
# S100A8           0.0278 -3.333800
#
# [2000 rows x 2 columns]

# %%
scvi_lfc_ta=scvi_lfc_ta.loc[blca.columns.intersection(scvi_lfc_ta.index)]
scvi_lfc_ta
#Papillary vs rest (basal and luminal invasive)
# Out:
#           proba_not_de  lfc_mean
# TSPAN6          0.2088  0.474446
# GCLC            0.0970  0.922369
# CD99            0.1164 -0.357701
# HS3ST1          0.1148  0.152747
# TMEM176A        0.0646  1.065262
# ...                ...       ...
# CCL3L3          0.1322  0.090164
# MARCKS          0.2112  0.167338
# CCL3            0.1116 -0.247941
# CISD3           0.1524  0.019287
# ADORA3          0.0896  0.575551
#
# [1773 rows x 2 columns]

# %%
blca_lm=blca[blca.columns.intersection(scvi_lfc_ta.index)]
display(blca_lm)
# Out:
#               TSPAN6      GCLC       CD99    HS3ST1  TMEM176A      TFPI  \
# ACH-001113  4.331992  6.500005   5.941576  0.097611  0.000000  0.056584
# ACH-001289  4.567424  4.221877   6.759688  0.084064  0.056584  0.056584
# ACH-001339  3.150560  3.682573   8.295998  0.422233  0.201634  4.060912
# ACH-001538  5.085340  4.489928   6.909413  2.718088  0.070389  3.317594
# ACH-000242  6.729417  7.127117   7.208283  3.005400  0.000000  0.855990
# ...              ...       ...        ...       ...       ...       ...
# ACH-000285  0.056584  4.829850   5.217618  0.632268  0.000000  0.250962
# ACH-002669  3.111031  4.472488   6.550131  1.735522  3.580145  6.744430
# ACH-001858  4.390943  5.410748   8.545853  0.757023  0.000000  8.195692
# ACH-001997  5.057450  4.469886   7.018256  2.226509  0.422233  5.441616
# ACH-000052  4.249445  3.945795  11.303210  0.000000  4.389567  5.515700
#
#                 ARF5    PLXND1     RECQL      PDK4  ...      CCL4     FCGBP  \
# ACH-001113  7.055174  5.289834  6.505097  0.000000  ...  0.000000  0.084064
# ACH-001289  7.561861  3.769772  5.390255  0.000000  ...  0.000000  0.070389
# ACH-001339  6.686781  7.216746  6.234961  1.378512  ...  0.214125  0.014355
# ACH-001538  6.980254  0.948601  5.638943  2.430285  ...  0.659925  0.028569
# ACH-000242  7.428276  2.518535  4.836429  1.007196  ...  0.056584  1.163499
# ...              ...       ...       ...       ...  ...       ...       ...
# ACH-000285  7.767125  3.195348  6.551208  0.028569  ...  0.163499  1.580145
# ACH-002669  7.206331  4.947666  5.870858  0.495695  ...  0.084064  0.124328
# ACH-001858  7.899357  6.558115  6.041988  0.941106  ...  0.000000  0.176323
# ACH-001997  7.922495  4.145677  5.310704  1.454176  ...  0.000000  0.992768
# ACH-000052  7.151981  4.861955  5.331275  0.056584  ...  0.000000  3.914565
#
#                CCL15     UHRF1    CCL4L2    CCL3L3    MARCKS      CCL3  \
# ACH-001113  0.000000  5.223423  0.097611  0.214125  6.817751  0.000000
# ACH-001289  0.000000  4.595742  0.097611  0.000000  4.741467  0.150560
# ACH-001339  0.000000  3.903038  0.000000  0.176323  5.954662  1.035624
# ACH-001538  0.056584  3.782409  0.000000  0.000000  6.244126  0.722466
# ACH-000242  0.918386  6.211986  0.000000  0.000000  5.599913  0.097611
# ...              ...       ...       ...       ...       ...       ...
# ACH-000285  0.042644  7.921781  0.000000  0.042644  4.488001  1.070389
# ACH-002669  0.000000  3.634593  0.226509  2.422233  3.903038  1.490570
# ACH-001858  0.000000  3.752749  0.000000  0.000000  6.637349  0.000000
# ACH-001997  0.000000  5.293150  0.000000  0.000000  5.920293  0.263034
# ACH-000052  0.042644  6.674687  0.000000  0.000000  4.811985  0.163499
#
#                CISD3    ADORA3
# ACH-001113  4.187451  0.000000
# ACH-001289  3.640390  0.028569
# ACH-001339  4.566815  0.137504
# ACH-001538  3.491853  0.000000
# ACH-000242  4.571070  0.000000
# ...              ...       ...
# ACH-000285  3.825786  0.056584
# ACH-002669  3.171527  0.000000
# ACH-001858  4.233428  0.028569
# ACH-001997  4.662775  0.000000
# ACH-000052  2.863938  0.000000
#
# [1517 rows x 1773 columns]

# %%
DPD_df = pd.DataFrame(
    np.zeros((len(blca_lm), 1)),
    index = list(blca_lm.index),
    columns = ['invasiveness'],
)
for exp_id in DPD_df.index:
    DPD_df.loc[exp_id, 'invasiveness'] = np.dot(blca_lm.loc[exp_id], scvi_lfc_ta['lfc_mean'])

display(DPD_df)
# Out:
#             invasiveness
# ACH-001113   -550.721389
# ACH-001289   -507.295265
# ACH-001339   -699.813968
# ACH-001538   -353.053727
# ACH-000242     85.113497
# ...                  ...
# ACH-000285   -808.317595
# ACH-002669   -500.855641
# ACH-001858   -418.874928
# ACH-001997   -131.478383
# ACH-000052   -666.151890
#
# [1517 rows x 1 columns]

# %%
DPD_cell_lines= DPD_df.loc[DPD_df.index.isin(cell_lines_all.index)]

# %%
DPD_cell_lines
# Out:
#             invasiveness
# ACH-000242     85.113497
# ACH-001409   -252.469816
# ACH-001414   -204.117377
# ACH-000566   -482.344675
# ACH-001412   -242.725810
# ACH-001407   -742.897420
# ACH-000896   -386.271296
# ACH-001413   -571.957462
# ACH-000545   -248.640068
# ACH-001415    103.493340
# ACH-000834    -58.591626
# ACH-001183    -66.528092
# ACH-000486   -399.073620
# ACH-000396   -524.500164
# ACH-000724   -269.779548
# ACH-000522   -642.657094
# ACH-000753   -641.729182
# ACH-000547   -162.073684
# ACH-000018   -631.710524
# ACH-000142   -149.143997
# ACH-000741   -258.977767
# ACH-000905   -420.705996
# ACH-000026   -620.302284
# ACH-000802   -220.060275
# ACH-000011   -484.437093
# ACH-000473      6.725847
# ACH-001416    149.082879
# ACH-000862    336.505436
# ACH-000593   -573.265111
# ACH-001410   -212.457437
# ACH-000720   -345.473716
# ACH-000384     77.875909
# ACH-000127   -555.393765

# %%
for i in DPD_cell_lines.index:
    DPD_cell_lines.loc[i,'cell_line_name'] = cell_lines_all.loc[i,'Cell Line']
# Out:
# /tmp/ipykernel_106222/3148374158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DPD_cell_lines.loc[i,'cell_line_name'] = cell_lines_all.loc[i,'Cell Line']

# %%
DPD_cell_lines.sort_values('invasiveness',ascending=False)
#KMBC2, UMUC7, UMUC14, RT112, UMUC1 and UMUC9, RT4 were classified as luminal subtype
#UMUC1 had high expression of both luminal and basal markers  PMID: 27924948
# Out:
#             invasiveness cell_line_name
# ACH-000862    336.505436          KMBC2
# ACH-001416    149.082879          UMUC9
# ACH-001415    103.493340          UMUC7
# ACH-000242     85.113497            RT4
# ACH-000384     77.875909          SW780
# ACH-000473      6.725847          RT112
# ACH-000834    -58.591626          UMUC1
# ACH-001183    -66.528092        RT11284
# ACH-000142   -149.143997          CAL29
# ACH-000547   -162.073684         HT1197
# ACH-001414   -204.117377          UMUC6
# ACH-001410   -212.457437          UMUC4
# ACH-000802   -220.060275        BFTC905
# ACH-001412   -242.725810         UMUC10
# ACH-000545   -248.640068         VMCUB1
# ACH-001409   -252.469816         UMUC16
# ACH-000741   -258.977767          UBLC1
# ACH-000724   -269.779548         HT1376
# ACH-000720   -345.473716         TCCSUP
# ACH-000896   -386.271296           647V
# ACH-000486   -399.073620         KU1919
# ACH-000905   -420.705996           5637
# ACH-000566   -482.344675         SW1710
# ACH-000011   -484.437093           253J
# ACH-000396   -524.500164            J82
# ACH-000127   -555.393765          SLR20
# ACH-001413   -571.957462         UMUC11
# ACH-000593   -573.265111           BC3C
# ACH-000026   -620.302284         253JBV
# ACH-000018   -631.710524            T24
# ACH-000753   -641.729182          JMSU1
# ACH-000522   -642.657094          UMUC3
# ACH-001407   -742.897420         UMUC13

# %%
scvi_lfc_df= scvi_lfc.iloc[2000:4000][['Gene','lfc_mean']]
scvi_lfc_df
# Out:
#                          Gene   lfc_mean
# comparison
# cluster1_T2 vs Rest    S100A8  11.116735
# NaN                      TCHH   8.430903
# NaN                     LYNX1   7.749890
# NaN                    S100A9   7.666663
# NaN                  SERPINB4   7.538958
# ...                       ...        ...
# NaN                    SPOCD1  -6.174197
# NaN                      TESC  -6.383301
# NaN                    IGFBP2  -7.289587
# NaN                    IGFBP5  -7.476717
# NaN                    SPINK1  -8.148858
#
# [2000 rows x 2 columns]

# %%
scvi_lfc_df.reset_index(inplace=True)
scvi_lfc_df.drop(columns=['comparison'],inplace=True)
scvi_lfc_df.set_index('Gene',inplace=True)
scvi_lfc_df
# Out:
#            lfc_mean
# Gene
# S100A8    11.116735
# TCHH       8.430903
# LYNX1      7.749890
# S100A9     7.666663
# SERPINB4   7.538958
# ...             ...
# SPOCD1    -6.174197
# TESC      -6.383301
# IGFBP2    -7.289587
# IGFBP5    -7.476717
# SPINK1    -8.148858
#
# [2000 rows x 1 columns]

# %%
blca_lm=blca[blca.columns.intersection(scvi_lfc_df.index)]
display(blca_lm)
# Out:
#               TSPAN6      GCLC       CD99    HS3ST1  TMEM176A      TFPI  \
# ACH-001113  4.331992  6.500005   5.941576  0.097611  0.000000  0.056584
# ACH-001289  4.567424  4.221877   6.759688  0.084064  0.056584  0.056584
# ACH-001339  3.150560  3.682573   8.295998  0.422233  0.201634  4.060912
# ACH-001538  5.085340  4.489928   6.909413  2.718088  0.070389  3.317594
# ACH-000242  6.729417  7.127117   7.208283  3.005400  0.000000  0.855990
# ...              ...       ...        ...       ...       ...       ...
# ACH-000285  0.056584  4.829850   5.217618  0.632268  0.000000  0.250962
# ACH-002669  3.111031  4.472488   6.550131  1.735522  3.580145  6.744430
# ACH-001858  4.390943  5.410748   8.545853  0.757023  0.000000  8.195692
# ACH-001997  5.057450  4.469886   7.018256  2.226509  0.422233  5.441616
# ACH-000052  4.249445  3.945795  11.303210  0.000000  4.389567  5.515700
#
#                 ARF5    PLXND1     RECQL      PDK4  ...      CCL4     FCGBP  \
# ACH-001113  7.055174  5.289834  6.505097  0.000000  ...  0.000000  0.084064
# ACH-001289  7.561861  3.769772  5.390255  0.000000  ...  0.000000  0.070389
# ACH-001339  6.686781  7.216746  6.234961  1.378512  ...  0.214125  0.014355
# ACH-001538  6.980254  0.948601  5.638943  2.430285  ...  0.659925  0.028569
# ACH-000242  7.428276  2.518535  4.836429  1.007196  ...  0.056584  1.163499
# ...              ...       ...       ...       ...  ...       ...       ...
# ACH-000285  7.767125  3.195348  6.551208  0.028569  ...  0.163499  1.580145
# ACH-002669  7.206331  4.947666  5.870858  0.495695  ...  0.084064  0.124328
# ACH-001858  7.899357  6.558115  6.041988  0.941106  ...  0.000000  0.176323
# ACH-001997  7.922495  4.145677  5.310704  1.454176  ...  0.000000  0.992768
# ACH-000052  7.151981  4.861955  5.331275  0.056584  ...  0.000000  3.914565
#
#                CCL15     UHRF1    CCL4L2    CCL3L3    MARCKS      CCL3  \
# ACH-001113  0.000000  5.223423  0.097611  0.214125  6.817751  0.000000
# ACH-001289  0.000000  4.595742  0.097611  0.000000  4.741467  0.150560
# ACH-001339  0.000000  3.903038  0.000000  0.176323  5.954662  1.035624
# ACH-001538  0.056584  3.782409  0.000000  0.000000  6.244126  0.722466
# ACH-000242  0.918386  6.211986  0.000000  0.000000  5.599913  0.097611
# ...              ...       ...       ...       ...       ...       ...
# ACH-000285  0.042644  7.921781  0.000000  0.042644  4.488001  1.070389
# ACH-002669  0.000000  3.634593  0.226509  2.422233  3.903038  1.490570
# ACH-001858  0.000000  3.752749  0.000000  0.000000  6.637349  0.000000
# ACH-001997  0.000000  5.293150  0.000000  0.000000  5.920293  0.263034
# ACH-000052  0.042644  6.674687  0.000000  0.000000  4.811985  0.163499
#
#                CISD3    ADORA3
# ACH-001113  4.187451  0.000000
# ACH-001289  3.640390  0.028569
# ACH-001339  4.566815  0.137504
# ACH-001538  3.491853  0.000000
# ACH-000242  4.571070  0.000000
# ...              ...       ...
# ACH-000285  3.825786  0.056584
# ACH-002669  3.171527  0.000000
# ACH-001858  4.233428  0.028569
# ACH-001997  4.662775  0.000000
# ACH-000052  2.863938  0.000000
#
# [1517 rows x 1773 columns]

# %%
scvi_lfc_df_int=scvi_lfc_df.loc[blca.columns.intersection(scvi_lfc_df.index)]
scvi_lfc_df_int
# Out:
#           lfc_mean
# TSPAN6   -0.234558
# GCLC     -1.773214
# CD99      0.257408
# HS3ST1   -1.921947
# TMEM176A  0.468119
# ...            ...
# CCL3L3    1.492260
# MARCKS    1.338571
# CCL3      1.823231
# CISD3    -0.080692
# ADORA3    2.339425
#
# [1773 rows x 1 columns]

# %%
DPD_df_1 = pd.DataFrame(
    np.zeros((len(blca_lm), 1)),
    index = list(blca_lm.index),
    columns = ['invasiveness'],
)

# %%
for exp_id in DPD_df_1.index:
    DPD_df_1.loc[exp_id, 'invasiveness'] = np.dot(blca_lm.loc[exp_id], scvi_lfc_df_int['lfc_mean'])

display(DPD_df)
# Out:
#             invasiveness
# ACH-001113   -550.721389
# ACH-001289   -507.295265
# ACH-001339   -699.813968
# ACH-001538   -353.053727
# ACH-000242     85.113497
# ...                  ...
# ACH-000285   -808.317595
# ACH-002669   -500.855641
# ACH-001858   -418.874928
# ACH-001997   -131.478383
# ACH-000052   -666.151890
#
# [1517 rows x 1 columns]

# %%
for i in DPD_cell_lines.index:
    DPD_cell_lines.loc[i,'cell_line_name'] = cell_lines_all.loc[i,'Cell Line']

# %%
DPD_cell_lines['Invasiveness_T2'] = 0 

for i in DPD_cell_lines.index:
    DPD_cell_lines.loc[i,'Invasiveness_T2'] =DPD_df_1.loc[i,'invasiveness']
# Out:
# /tmp/ipykernel_106222/728566714.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   DPD_cell_lines['Invasiveness_T2'] = 0
# /tmp/ipykernel_106222/728566714.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '468.987188509435' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   DPD_cell_lines.loc[i,'Invasiveness_T2'] =DPD_df_1.loc[i,'invasiveness']

# %%
DPD_cell_lines.sort_values('Invasiveness_T2',ascending=True)
# Out:
#             invasiveness cell_line_name  Invasiveness_T2
# ACH-000242     85.113497            RT4       468.987189
# ACH-001416    149.082879          UMUC9      1054.998495
# ACH-001410   -212.457437          UMUC4      1318.999128
# ACH-000862    336.505436          KMBC2      1328.405751
# ACH-000384     77.875909          SW780      1359.179001
# ACH-000011   -484.437093           253J      1411.240089
# ACH-000834    -58.591626          UMUC1      1494.046376
# ACH-000741   -258.977767          UBLC1      1509.766302
# ACH-001414   -204.117377          UMUC6      1577.455887
# ACH-001415    103.493340          UMUC7      1590.210228
# ACH-000127   -555.393765          SLR20      1637.274755
# ACH-001183    -66.528092        RT11284      1641.076889
# ACH-000026   -620.302284         253JBV      1641.900122
# ACH-000896   -386.271296           647V      1661.289655
# ACH-000142   -149.143997          CAL29      1671.339754
# ACH-000566   -482.344675         SW1710      1713.847158
# ACH-000720   -345.473716         TCCSUP      1721.978636
# ACH-000396   -524.500164            J82      1741.714541
# ACH-000547   -162.073684         HT1197      1743.998227
# ACH-000473      6.725847          RT112      1748.229055
# ACH-000905   -420.705996           5637      1759.023365
# ACH-000018   -631.710524            T24      1842.661612
# ACH-000522   -642.657094          UMUC3      1853.109062
# ACH-000753   -641.729182          JMSU1      1868.759002
# ACH-001409   -252.469816         UMUC16      1891.984806
# ACH-001407   -742.897420         UMUC13      1917.457935
# ACH-001413   -571.957462         UMUC11      2021.411453
# ACH-000486   -399.073620         KU1919      2034.277123
# ACH-000802   -220.060275        BFTC905      2072.744310
# ACH-001412   -242.725810         UMUC10      2095.007557
# ACH-000593   -573.265111           BC3C      2112.445716
# ACH-000545   -248.640068         VMCUB1      2262.922519
# ACH-000724   -269.779548         HT1376      2330.059510

# %%
import seaborn as sns
sns.scatterplot(DPD_cell_lines,y='invasiveness',x='Invasiveness_T2',hue='cell_line_name')
plt.axvline(x=0,linestyle='--')
plt.axhline(y=0,linestyle='--')
plt.title("DPDs Visualization of cell lines")
plt.legend(bbox_to_anchor=(1,0, 0,1))
